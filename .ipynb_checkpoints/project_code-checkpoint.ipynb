# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
model=RandomForestClassifier()

# %%
dataset=pd.read_csv("diabetes.csv")

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
features=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
scores = cross_val_score(model, dataset[features], dataset["Outcome"], cv=5)
scores
# Out:
# array([0.72727273, 0.74675325, 0.76623377, 0.81045752, 0.73202614])

# %%
scores = cross_val_score(RandomForestClassifier(n_estimators = 2), dataset[features], dataset["Outcome"], cv=5)
scores
# Out:
# array([0.74675325, 0.68831169, 0.72077922, 0.74509804, 0.7124183 ])

# %%
np.mean(scores)
# Out:
# 0.7226720991426874

# %%
mydict={"n_estimators":100,"max_depth":1}

# %%
def get_fitness(model,parameters):
    our_model=model(**parameters)
    return np.mean(cross_val_score(our_model, dataset[features], dataset["Outcome"], cv=4))

# %%
get_fitness(RandomForestClassifier,mydict)
# Out:
# 0.6757812499999999

# %%
import random as rnd
#my_range={"n_estimators":(100,500),"max_depth":(1,30)}
def mutate(mydict):
    key= rnd.choice(list(mydict.keys()))
    if (isinstance(mydict[key],float)):
        guess=mydict[key]+ 0.05*rnd.uniform(1,3)
    else:
        guess= int(mydict[key]+ rnd.uniform(1,3))

    mydict[key] = guess
    return mydict
mutate({'n_estimators': 100, 'ccp_alpha':0.1, 'max_depth': 12})
# Out:
# {'n_estimators': 101, 'ccp_alpha': 0.1, 'max_depth': 12}

# %%
def create_population(parameters, number):
    population = []
    for i in range(number):
        my_dict = {}
        for parameter in parameters:
            value = parameters[parameter]
            if type(value) == float:
                value *= rnd.uniform(0,2)
                my_dict[parameter] = value
            else:
                value = int(value*rnd.uniform(0,3))
                my_dict[parameter] = value+1
        population.append(my_dict)
    return population
#create_population({'n_estimators' : 100, 'ccp_alpha' : 0.02})

# %%
def roulette_selection(fitness_values, model):
    total = sum(fitness_values)
    ranks = [fitness/total for fitness in fitness_values]
    selected_parents = rnd.choices([i for i in range(len(population))], weights = ranks, k = 2) 
    return selected_parents

# %%
population = create_population({'n_estimators' : 100, 'ccp_alpha' : 0.02})
fitness_values = [get_fitness(model, child) for child in population]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-14e89245f53f> in <module>
# ----> 1 population = create_population({'n_estimators' : 100, 'ccp_alpha' : 0.02})
#       2 fitness_values = [get_fitness(model, child) for child in population]
#
# TypeError: create_population() missing 1 required positional argument: 'number'

# %%
parents = roulette_selection(fitness_values, RandomForestClassifier)

# %%
population = create_population({'min_samples_leaf':2,'min_samples_split':2,'n_estimators' : 100, 'ccp_alpha' : 0.02, 'max_depth':10}, 20)

# %%
population[3]

# %%
get_fitness(model, population[3])

# %%
def crossover(parent1, parent2):
    index = rnd.choice(list(parent1.keys()))
    parent1[index], parent2[index] = parent2[index], parent1[index]
    return parent1, parent2

crossover({"n_estimators":100,"max_depth":1},{"n_estimators":140,"max_depth":2})
# Out:
# ({'n_estimators': 100, 'max_depth': 2}, {'n_estimators': 140, 'max_depth': 1})

# %%
model = RandomForestClassifier
population = create_population({'min_samples_leaf':5,'n_estimators' : 100, 'ccp_alpha' : 0.02, 'max_depth':10}, 100)
print('Calculating Fitness values!')
fitness_values = [get_fitness(model, child) for child in population]
for i in range(1000):
    print('Doing roulette selection, round', i)
    #roulette selection - probability of selection is proportional to fitness score
    parents = roulette_selection(fitness_values, model)
    print('Doing crossover, round', i)
    #crossover
    #population[parents[0]],population[parents[1]]= crossover(population[parents[0]], population[parents[1]])
    crossover0, crossover1 = crossover(population[parents[0]], population[parents[1]])
    fitness_score_parent0=get_fitness(model, crossover0)
    fitness_score_parent1=get_fitness(model, crossover1)
    if fitness_values[parents[0]]<fitness_score_parent0:
        population[parents[0]] = crossover0
        fitness_values[parents[0]] = fitness_score_parent0
    if fitness_values[parents[1]]<fitness_score_parent1:
        population[parents[1]] = crossover1
        fitness_values[parents[1]] = fitness_score_parent1
    #fitness_values[parents[0]], fitness_values[parents[1]] = fitness_score_parent0, fitness_score_parent1
    print('Doing mutation, round', i)
    #mutation - accepted only if it makes population better
    to_be_mutated = rnd.randint(0,len(population)-1)
    child = population[to_be_mutated]
    child_fitness = get_fitness(RandomForestClassifier,child)
    mutation = mutate(child)
    mutation_fitness=get_fitness(RandomForestClassifier,mutation)        
    if mutation_fitness>child_fitness:
        population[to_be_mutated] = mutation
        fitness_values[to_be_mutated] = mutation_fitness
    max_score = max(fitness_values)
    print('Max fitness score for now is', max_score, 'for parameters', population[fitness_values.index(max_score)])
# Out:
# Calculating Fitness values!
# Doing roulette selection, round 0
# Doing crossover, round 0
# Doing mutation, round 0
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 1
# Doing crossover, round 1
# Doing mutation, round 1
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 2
# Doing crossover, round 2
# Doing mutation, round 2
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 3
# Doing crossover, round 3
# Doing mutation, round 3
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 4
# Doing crossover, round 4
# Doing mutation, round 4
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 5
# Doing crossover, round 5
# Doing mutation, round 5
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 6
# Doing crossover, round 6
# Doing mutation, round 6
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 7
# Doing crossover, round 7
# Doing mutation, round 7
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 181, 'ccp_alpha': 0.0017563326982396933, 'max_depth': 6}
# Doing roulette selection, round 8
# Doing crossover, round 8
# Doing mutation, round 8
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 9
# Doing crossover, round 9
# Doing mutation, round 9
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 10
# Doing crossover, round 10
# Doing mutation, round 10
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 11
# Doing crossover, round 11
# Doing mutation, round 11
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 12
# Doing crossover, round 12
# Doing mutation, round 12
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 13
# Doing crossover, round 13
# Doing mutation, round 13
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 14
# Doing crossover, round 14
# Doing mutation, round 14
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 15
# Doing crossover, round 15
# Doing mutation, round 15
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 16
# Doing crossover, round 16
# Doing mutation, round 16
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 17
# Doing crossover, round 17
# Doing mutation, round 17
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 18
# Doing crossover, round 18
# Doing mutation, round 18
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 19
# Doing crossover, round 19
# Doing mutation, round 19
# Max fitness score for now is 0.7760416666666667 for parameters {'min_samples_leaf': 3, 'n_estimators': 159, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 20
# Doing crossover, round 20
# Doing mutation, round 20
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 21
# Doing crossover, round 21
# Doing mutation, round 21
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 22
# Doing crossover, round 22
# Doing mutation, round 22
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 23
# Doing crossover, round 23
# Doing mutation, round 23
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 24
# Doing crossover, round 24
# Doing mutation, round 24
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 25
# Doing crossover, round 25
# Doing mutation, round 25
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 26
# Doing crossover, round 26
# Doing mutation, round 26
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 27
# Doing crossover, round 27
# Doing mutation, round 27
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 28
# Doing crossover, round 28
# Doing mutation, round 28
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 29
# Doing crossover, round 29
# Doing mutation, round 29
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 30
# Doing crossover, round 30
# Doing mutation, round 30
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 31
# Doing crossover, round 31
# Doing mutation, round 31
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 32
# Doing crossover, round 32
# Doing mutation, round 32
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 33
# Doing crossover, round 33
# Doing mutation, round 33
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 15}
# Doing roulette selection, round 34
# Doing crossover, round 34
# Doing mutation, round 34
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 35
# Doing crossover, round 35
# Doing mutation, round 35
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 36
# Doing crossover, round 36
# Doing mutation, round 36
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 37
# Doing crossover, round 37
# Doing mutation, round 37
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 38
# Doing crossover, round 38
# Doing mutation, round 38
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 39
# Doing crossover, round 39
# Doing mutation, round 39
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 40
# Doing crossover, round 40
# Doing mutation, round 40
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 41
# Doing crossover, round 41
# Doing mutation, round 41
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 42
# Doing crossover, round 42
# Doing mutation, round 42
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 43
# Doing crossover, round 43
# Doing mutation, round 43
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 44
# Doing crossover, round 44
# Doing mutation, round 44
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 45
# Doing crossover, round 45
# Doing mutation, round 45
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 46
# Doing crossover, round 46
# Doing mutation, round 46
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 47
# Doing crossover, round 47
# Doing mutation, round 47
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 48
# Doing crossover, round 48
# Doing mutation, round 48
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 49
# Doing crossover, round 49
# Doing mutation, round 49
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 50
# Doing crossover, round 50
# Doing mutation, round 50
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 51
# Doing crossover, round 51
# Doing mutation, round 51
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 52
# Doing crossover, round 52
# Doing mutation, round 52
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 53
# Doing crossover, round 53
# Doing mutation, round 53
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 3, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 54
# Doing crossover, round 54
# Doing mutation, round 54
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 55
# Doing crossover, round 55
# Doing mutation, round 55
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 56
# Doing crossover, round 56
# Doing mutation, round 56
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 57
# Doing crossover, round 57
# Doing mutation, round 57
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 58
# Doing crossover, round 58
# Doing mutation, round 58
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 59
# Doing crossover, round 59
# Doing mutation, round 59
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 60
# Doing crossover, round 60
# Doing mutation, round 60
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 61
# Doing crossover, round 61
# Doing mutation, round 61
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 62
# Doing crossover, round 62
# Doing mutation, round 62
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 63
# Doing crossover, round 63
# Doing mutation, round 63
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 64
# Doing crossover, round 64
# Doing mutation, round 64
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 65
# Doing crossover, round 65
# Doing mutation, round 65
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 66
# Doing crossover, round 66
# Doing mutation, round 66
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 67
# Doing crossover, round 67
# Doing mutation, round 67
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 68
# Doing crossover, round 68
# Doing mutation, round 68
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 69
# Doing crossover, round 69
# Doing mutation, round 69
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 70
# Doing crossover, round 70
# Doing mutation, round 70
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 71
# Doing crossover, round 71
# Doing mutation, round 71
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 72
# Doing crossover, round 72
# Doing mutation, round 72
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 73
# Doing crossover, round 73
# Doing mutation, round 73
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 74
# Doing crossover, round 74
# Doing mutation, round 74
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 75
# Doing crossover, round 75
# Doing mutation, round 75
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 76
# Doing crossover, round 76
# Doing mutation, round 76
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 77
# Doing crossover, round 77
# Doing mutation, round 77
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 78
# Doing crossover, round 78
# Doing mutation, round 78
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 79
# Doing crossover, round 79
# Doing mutation, round 79
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 80
# Doing crossover, round 80
# Doing mutation, round 80
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 81
# Doing crossover, round 81
# Doing mutation, round 81
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 82
# Doing crossover, round 82
# Doing mutation, round 82
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 83
# Doing crossover, round 83
# Doing mutation, round 83
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 84
# Doing crossover, round 84
# Doing mutation, round 84
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 85
# Doing crossover, round 85
# Doing mutation, round 85
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 86
# Doing crossover, round 86
# Doing mutation, round 86
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 87
# Doing crossover, round 87
# Doing mutation, round 87
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 88
# Doing crossover, round 88
# Doing mutation, round 88
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 89
# Doing crossover, round 89
# Doing mutation, round 89
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 90
# Doing crossover, round 90
# Doing mutation, round 90
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 91
# Doing crossover, round 91
# Doing mutation, round 91
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 92
# Doing crossover, round 92
# Doing mutation, round 92
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 93
# Doing crossover, round 93
# Doing mutation, round 93
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 94
# Doing crossover, round 94
# Doing mutation, round 94
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 95
# Doing crossover, round 95
# Doing mutation, round 95
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 96
# Doing crossover, round 96
# Doing mutation, round 96
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 97
# Doing crossover, round 97
# Doing mutation, round 97
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 98
# Doing crossover, round 98
# Doing mutation, round 98
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 99
# Doing crossover, round 99
# Doing mutation, round 99
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 100
# Doing crossover, round 100
# Doing mutation, round 100
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 101
# Doing crossover, round 101
# Doing mutation, round 101
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 102
# Doing crossover, round 102
# Doing mutation, round 102
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 103
# Doing crossover, round 103
# Doing mutation, round 103
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 104
# Doing crossover, round 104
# Doing mutation, round 104
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 105
# Doing crossover, round 105
# Doing mutation, round 105
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 106
# Doing crossover, round 106
# Doing mutation, round 106
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 107
# Doing crossover, round 107
# Doing mutation, round 107
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 108
# Doing crossover, round 108
# Doing mutation, round 108
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 109
# Doing crossover, round 109
# Doing mutation, round 109
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 110
# Doing crossover, round 110
# Doing mutation, round 110
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 111
# Doing crossover, round 111
# Doing mutation, round 111
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 112
# Doing crossover, round 112
# Doing mutation, round 112
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 113
# Doing crossover, round 113
# Doing mutation, round 113
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 114
# Doing crossover, round 114
# Doing mutation, round 114
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 115
# Doing crossover, round 115
# Doing mutation, round 115
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 116
# Doing crossover, round 116
# Doing mutation, round 116
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 117
# Doing crossover, round 117
# Doing mutation, round 117
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 118
# Doing crossover, round 118
# Doing mutation, round 118
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 119
# Doing crossover, round 119
# Doing mutation, round 119
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 120
# Doing crossover, round 120
# Doing mutation, round 120
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 121
# Doing crossover, round 121
# Doing mutation, round 121
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 122
# Doing crossover, round 122
# Doing mutation, round 122
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 123
# Doing crossover, round 123
# Doing mutation, round 123
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 124
# Doing crossover, round 124
# Doing mutation, round 124
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 125
# Doing crossover, round 125
# Doing mutation, round 125
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 126
# Doing crossover, round 126
# Doing mutation, round 126
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 127
# Doing crossover, round 127
# Doing mutation, round 127
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 128
# Doing crossover, round 128
# Doing mutation, round 128
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 129
# Doing crossover, round 129
# Doing mutation, round 129
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 130
# Doing crossover, round 130
# Doing mutation, round 130
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 131
# Doing crossover, round 131
# Doing mutation, round 131
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 132
# Doing crossover, round 132
# Doing mutation, round 132
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 133
# Doing crossover, round 133
# Doing mutation, round 133
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 134
# Doing crossover, round 134
# Doing mutation, round 134
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 135
# Doing crossover, round 135
# Doing mutation, round 135
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 136
# Doing crossover, round 136
# Doing mutation, round 136
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 137
# Doing crossover, round 137
# Doing mutation, round 137
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 138
# Doing crossover, round 138
# Doing mutation, round 138
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 139
# Doing crossover, round 139
# Doing mutation, round 139
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 140
# Doing crossover, round 140
# Doing mutation, round 140
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 30}
# Doing roulette selection, round 141
# Doing crossover, round 141
# Doing mutation, round 141
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 142
# Doing crossover, round 142
# Doing mutation, round 142
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 143
# Doing crossover, round 143
# Doing mutation, round 143
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 144
# Doing crossover, round 144
# Doing mutation, round 144
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 145
# Doing crossover, round 145
# Doing mutation, round 145
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 146
# Doing crossover, round 146
# Doing mutation, round 146
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 147
# Doing crossover, round 147
# Doing mutation, round 147
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 148
# Doing crossover, round 148
# Doing mutation, round 148
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 149
# Doing crossover, round 149
# Doing mutation, round 149
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 150
# Doing crossover, round 150
# Doing mutation, round 150
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 151
# Doing crossover, round 151
# Doing mutation, round 151
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 152
# Doing crossover, round 152
# Doing mutation, round 152
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 153
# Doing crossover, round 153
# Doing mutation, round 153
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 154
# Doing crossover, round 154
# Doing mutation, round 154
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 155
# Doing crossover, round 155
# Doing mutation, round 155
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 156
# Doing crossover, round 156
# Doing mutation, round 156
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 157
# Doing crossover, round 157
# Doing mutation, round 157
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 158
# Doing crossover, round 158
# Doing mutation, round 158
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 159
# Doing crossover, round 159
# Doing mutation, round 159
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 160
# Doing crossover, round 160
# Doing mutation, round 160
# Max fitness score for now is 0.7786458333333334 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 23}
# Doing roulette selection, round 161
# Doing crossover, round 161
# Doing mutation, round 161
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 162
# Doing crossover, round 162
# Doing mutation, round 162
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 163
# Doing crossover, round 163
# Doing mutation, round 163
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 164
# Doing crossover, round 164
# Doing mutation, round 164
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 165
# Doing crossover, round 165
# Doing mutation, round 165
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 166
# Doing crossover, round 166
# Doing mutation, round 166
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 167
# Doing crossover, round 167
# Doing mutation, round 167
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 168
# Doing crossover, round 168
# Doing mutation, round 168
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 169
# Doing crossover, round 169
# Doing mutation, round 169
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 170
# Doing crossover, round 170
# Doing mutation, round 170
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 171
# Doing crossover, round 171
# Doing mutation, round 171
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 172
# Doing crossover, round 172
# Doing mutation, round 172
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 173
# Doing crossover, round 173
# Doing mutation, round 173
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 174
# Doing crossover, round 174
# Doing mutation, round 174
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 175
# Doing crossover, round 175
# Doing mutation, round 175
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 176
# Doing crossover, round 176
# Doing mutation, round 176
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 177
# Doing crossover, round 177
# Doing mutation, round 177
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 178
# Doing crossover, round 178
# Doing mutation, round 178
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 179
# Doing crossover, round 179
# Doing mutation, round 179
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 180
# Doing crossover, round 180
# Doing mutation, round 180
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 181
# Doing crossover, round 181
# Doing mutation, round 181
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 182
# Doing crossover, round 182
# Doing mutation, round 182
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 183
# Doing crossover, round 183
# Doing mutation, round 183
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 184
# Doing crossover, round 184
# Doing mutation, round 184
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 185
# Doing crossover, round 185
# Doing mutation, round 185
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 186
# Doing crossover, round 186
# Doing mutation, round 186
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 187
# Doing crossover, round 187
# Doing mutation, round 187
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 188
# Doing crossover, round 188
# Doing mutation, round 188
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 189
# Doing crossover, round 189
# Doing mutation, round 189
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 190
# Doing crossover, round 190
# Doing mutation, round 190
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 191
# Doing crossover, round 191
# Doing mutation, round 191
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 192
# Doing crossover, round 192
# Doing mutation, round 192
# Max fitness score for now is 0.78125 for parameters {'min_samples_leaf': 4, 'n_estimators': 187, 'ccp_alpha': 0.00015939317761104466, 'max_depth': 28}
# Doing roulette selection, round 193
# Doing crossover, round 193
# Doing mutation, round 193
# ...
# Doing mutation, round 935
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 936
# Doing crossover, round 936
# Doing mutation, round 936
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 937
# Doing crossover, round 937
# Doing mutation, round 937
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 938
# Doing crossover, round 938
# Doing mutation, round 938
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 939
# Doing crossover, round 939
# Doing mutation, round 939
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 940
# Doing crossover, round 940
# Doing mutation, round 940
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 941
# Doing crossover, round 941
# Doing mutation, round 941
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 942
# Doing crossover, round 942
# Doing mutation, round 942
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 943
# Doing crossover, round 943
# Doing mutation, round 943
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 944
# Doing crossover, round 944
# Doing mutation, round 944
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 945
# Doing crossover, round 945
# Doing mutation, round 945
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 946
# Doing crossover, round 946
# Doing mutation, round 946
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 947
# Doing crossover, round 947
# Doing mutation, round 947
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 948
# Doing crossover, round 948
# Doing mutation, round 948
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 949
# Doing crossover, round 949
# Doing mutation, round 949
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 950
# Doing crossover, round 950
# Doing mutation, round 950
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 951
# Doing crossover, round 951
# Doing mutation, round 951
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 952
# Doing crossover, round 952
# Doing mutation, round 952
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 953
# Doing crossover, round 953
# Doing mutation, round 953
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 954
# Doing crossover, round 954
# Doing mutation, round 954
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 955
# Doing crossover, round 955
# Doing mutation, round 955
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 956
# Doing crossover, round 956
# Doing mutation, round 956
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 957
# Doing crossover, round 957
# Doing mutation, round 957
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 958
# Doing crossover, round 958
# Doing mutation, round 958
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 959
# Doing crossover, round 959
# Doing mutation, round 959
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 960
# Doing crossover, round 960
# Doing mutation, round 960
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 961
# Doing crossover, round 961
# Doing mutation, round 961
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 962
# Doing crossover, round 962
# Doing mutation, round 962
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 963
# Doing crossover, round 963
# Doing mutation, round 963
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 964
# Doing crossover, round 964
# Doing mutation, round 964
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 965
# Doing crossover, round 965
# Doing mutation, round 965
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 966
# Doing crossover, round 966
# Doing mutation, round 966
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 967
# Doing crossover, round 967
# Doing mutation, round 967
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 968
# Doing crossover, round 968
# Doing mutation, round 968
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 969
# Doing crossover, round 969
# Doing mutation, round 969
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 970
# Doing crossover, round 970
# Doing mutation, round 970
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 971
# Doing crossover, round 971
# Doing mutation, round 971
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 972
# Doing crossover, round 972
# Doing mutation, round 972
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 973
# Doing crossover, round 973
# Doing mutation, round 973
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.38114200627036954, 'max_depth': 32}
# Doing roulette selection, round 974
# Doing crossover, round 974
# Doing mutation, round 974
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 975
# Doing crossover, round 975
# Doing mutation, round 975
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 976
# Doing crossover, round 976
# Doing mutation, round 976
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 977
# Doing crossover, round 977
# Doing mutation, round 977
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 978
# Doing crossover, round 978
# Doing mutation, round 978
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 979
# Doing crossover, round 979
# Doing mutation, round 979
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 980
# Doing crossover, round 980
# Doing mutation, round 980
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 981
# Doing crossover, round 981
# Doing mutation, round 981
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 982
# Doing crossover, round 982
# Doing mutation, round 982
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 983
# Doing crossover, round 983
# Doing mutation, round 983
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 984
# Doing crossover, round 984
# Doing mutation, round 984
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 985
# Doing crossover, round 985
# Doing mutation, round 985
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 986
# Doing crossover, round 986
# Doing mutation, round 986
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 987
# Doing crossover, round 987
# Doing mutation, round 987
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 988
# Doing crossover, round 988
# Doing mutation, round 988
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 989
# Doing crossover, round 989
# Doing mutation, round 989
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 990
# Doing crossover, round 990
# Doing mutation, round 990
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 991
# Doing crossover, round 991
# Doing mutation, round 991
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.47892632641076005, 'max_depth': 32}
# Doing roulette selection, round 992
# Doing crossover, round 992
# Doing mutation, round 992
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 993
# Doing crossover, round 993
# Doing mutation, round 993
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 994
# Doing crossover, round 994
# Doing mutation, round 994
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 995
# Doing crossover, round 995
# Doing mutation, round 995
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 996
# Doing crossover, round 996
# Doing mutation, round 996
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 997
# Doing crossover, round 997
# Doing mutation, round 997
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 998
# Doing crossover, round 998
# Doing mutation, round 998
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
# Doing roulette selection, round 999
# Doing crossover, round 999
# Doing mutation, round 999
# Max fitness score for now is 0.7747395833333334 for parameters {'min_samples_leaf': 5, 'n_estimators': 54, 'ccp_alpha': 0.29017838099113724, 'max_depth': 32}
